# %%
import sounds

# %%
rate, data = sounds.loadSound('swnotry.wav')

# %%
Audio(data=data, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## `scale`

# %%
Write a fun
